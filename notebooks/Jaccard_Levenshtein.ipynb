# %% [markdown]
# ###  Matching based on Jaccard distance
# Jaccard Distance is a measure of how dissimilar two sets are.  The lower the distance, the more similar the two strings.
# Jaccard Distance depends on another concept called “Jaccard Similarity Index” which is (the number in both sets) / (the number in either set) * 100
# J(X,Y) = |X∩Y| / |X∪Y|
#
# J(X,Y) = |X∩Y| / |X∪Y|
#
# Then we can calculate the Jaccard Distance as follows:
# Python
#  D(X,Y) = 1 – J(X,Y)
#
#  D(X,Y) = 1 – J(X,Y)

# %%
import pandas as pd
import nltk

# %%
df_dbpedia = pd.read_csv("./files/dbpedia_classes.csv")
df_imageNet = pd.read_csv("./files/ImageNet.csv")
df_imageNet['Class Name'] = df_imageNet['Class Name'].str.replace(", ",",")
df_imageNet['Class Name'] = df_imageNet['Class Name'].str.split(",")
df_imageNet.rename(columns = {"Class Name":"imageNet_class"}, inplace=True)

# %%
def get_min_jaccard_distance():
    min_jaccard_list = []
    min_label_list = []
    for class_list in df_imageNet['imageNet_class']:
        min_val = 1
        min_label = ''
        for item in class_list:
            for label in df_dbpedia['label']:
                if min_val> nltk.jaccard_distance(set(item), set(label)):
                    min_val = nltk.jaccard_distance(set(item), set(label))
                    min_label = label
        min_jaccard_list.append(min_val)
        min_label_list.append(min_label)
        
    df_imageNet['min_jaccard_distance'] = min_jaccard_list
    df_imageNet['dbpedia_class'] = min_label_list
            
get_min_jaccard_distance()

# %%
df_imageNet.sort_values(ascending = True, by= "min_jaccard_distance")[:50]
# Out:
#      Class ID                                     imageNet_class  \
# 751       751                      [racer, race car, racing car]
# 687       687                                [organ, pipe organ]
# 497       497                          [church, church building]
# 134       134                                      [crane, bird]
# 478       478                                           [carton]
# 553       553               [file, file cabinet, filing cabinet]
# 807       807       [solar dish, solar collector, solar furnace]
# 668       668                                           [mosque]
# 519       519                                            [crate]
# 355       355                                            [llama]
# 812       812                                    [space shuttle]
# 323       323  [monarch, monarch butterfly, milkweed butterfl...
# 483       483                                           [castle]
# 829       829   [streetcar, tram, tramcar, trolley, trolley car]
# 36         36                                         [terrapin]
# 832       832                                      [stupa, tope]
# 327       327                               [starfish, sea star]
# 242       242                                            [boxer]
# 624       624                                          [library]
# 663       663                                        [monastery]
# 916       916           [web site, website, internet site, site]
# 866       866                                          [tractor]
# 365       365     [orangutan, orang, orangutang, Pongo pygmaeus]
# 745       745                                        [projector]
# 399       399                                            [abaya]
# 743       743                             [prison, prison house]
# 404       404                                         [airliner]
# 405       405                               [airship, dirigible]
# 408       408                    [amphibian, amphibious vehicle]
# 66         66  [horned viper, cerastes, sand viper, horned as...
# 525       525                                  [dam, dike, dyke]
# 698       698                                           [palace]
# 762       762   [restaurant, eating house, eating place, eatery]
# 312       312                                          [cricket]
# 437       437         [beacon, lighthouse, beacon light, pharos]
# 981       981                      [ballplayer, baseball player]
# 980       980                                          [volcano]
# 979       979                                     [valley, vale]
# 998       998                            [ear, spike, capitulum]
# 706       706                                   [patio, terrace]
# 705       705                   [passenger car, coach, carriage]
# 286       286  [cougar, puma, catamount, mountain lion, paint...
# 487       487  [cellular telephone, cellular phone, cellphone...
# 510       510  [container ship, containership, container vessel]
# 755       755                 [radio telescope, radio reflector]
# 757       757                   [recreational vehicle, RV, R.V.]
# 117       117    [chambered nautilus, pearly nautilus, nautilus]
# 856       856            [thresher, thrasher, threshing machine]
# 495       495                      [china cabinet, china closet]
# 215       215                                 [Brittany spaniel]
#
#      min_jaccard_distance                                     dbpedia_class
# 751              0.000000                                              race
# 687              0.000000                                             organ
# 497              0.000000                                            church
# 134              0.000000                                              bird
# 478              0.000000                                           cartoon
# 553              0.000000                                              file
# 807              0.000000                                    roller coaster
# 668              0.000000                                            mosque
# 519              0.000000                                            crater
# 355              0.000000                                            mammal
# 812              0.000000                                     space shuttle
# 323              0.000000                                           monarch
# 483              0.000000                                            castle
# 829              0.000000                                         streetcar
# 36               0.000000                                           painter
# 832              0.000000                                              poet
# 327              0.000000                                         rest area
# 242              0.000000                                             boxer
# 624              0.000000                                           library
# 663              0.000000                                         monastery
# 916              0.000000                                           website
# 866              0.000000                                             actor
# 365              0.000000                                             organ
# 745              0.000000                                           project
# 399              0.000000                                               bay
# 743              0.000000                                            prison
# 404              0.000000                                           airline
# 405              0.000000                                            parish
# 408              0.000000                                         amphibian
# 66               0.000000                                         streetcar
# 525              0.000000                                               dam
# 698              0.000000                                             place
# 762              0.000000                                        restaurant
# 312              0.000000                                         cricketer
# 437              0.000000                                        lighthouse
# 981              0.000000                                   baseball player
# 980              0.000000                                           volcano
# 979              0.000000                                            valley
# 998              0.000000                                              area
# 706              0.000000                                            crater
# 705              0.000000                                             coach
# 286              0.000000                                           painter
# 487              0.000000                                      mobile phone
# 510              0.076923                                  historical event
# 755              0.076923                                 historical period
# 757              0.076923                                  historical event
# 117              0.083333                                     tennis player
# 856              0.083333                                animanga character
# 495              0.083333  national collegiate athletic association athlete
# 215              0.083333                                     tennis player

# %% [markdown]
# ### Evaluation
# With an overview, we could see that the jaccard-distance based string matching machted two words that has the same set of alphabets. That is inaccurate compared with fuzzy mathcing.

# %%
import nltk

# %%
img_net = pd.read_csv("./files/ImageNet.csv")
img_net_list = img_net["Class Name"].tolist()

dbpedia = pd.read_csv("./files/dbpedia_classes.csv")
db_list = dbpedia["label"].tolist()

# %%
dataframe_jaccard = pd.DataFrame(index =db_list ,columns =img_net_list)

# %%
for i in range(0,len(img_net_list)):
    for a in range(0,len(db_list)):
        if len(img_net_list[i].split(",")) > 1:
            max_val = 1.0
            for el in img_net_list[i].split(","):
                el_val = nltk.jaccard_distance(set(el), set(db_list[a]))
                #el_val = (len(el + db_list[a])) - len(set(el).intersection(db_list[a])) / (len(el + db_list[a]))
                if el_val < max_val:
                    max_val = el_val
            dataframe_jaccard.iat[a,i] = max_val
        else:
            first = set(img_net_list[i])
            second = set(db_list[a])
            dataframe_jaccard.iat[a,i] = nltk.jaccard_distance(first,second)

# %%
dataframe_jaccard
# Out:
#            tench, Tinca tinca goldfish, Carassius auratus  \
# company              0.727273                    0.928571
# activity             0.555556                    0.727273
# name                 0.714286                    0.909091
# person               0.777778                    0.833333
# actor                0.666667                         0.7
# ...                       ...                         ...
# Wind motor           0.666667                    0.692308
# Windmill             0.818182                    0.727273
# wine                 0.714286                    0.909091
# woman                     0.8                    0.916667
# zoo                       1.0                    0.888889
#
#            great white shark, white shark, man-eater, man-eating shark, Carcharodon caharias',  \
# company                                              0.733333
# activity                                             0.769231
# name                                                      0.5
# person                                               0.714286
# actor                                                0.692308
# ...                                                       ...
# Wind motor                                           0.583333
# Windmill                                                  0.8
# wine                                                 0.727273
# woman                                                     0.7
# zoo                                                  0.923077
#
#            tiger shark, Galeocerdo cuvieri hammerhead, hammerhead shark  \
# company                             0.8125                     0.818182
# activity                          0.714286                     0.909091
# name                              0.833333                     0.571429
# person                            0.769231                         0.75
# actor                             0.692308                     0.777778
# ...                                    ...                          ...
# Wind motor                          0.6875                     0.714286
# Windmill                               0.8                          0.8
# wine                              0.833333                     0.888889
# woman                             0.866667                     0.777778
# zoo                               0.923077                          1.0
#
#            electric ray, crampfish, numbfish, torpedo  stingray      cock  \
# company                                      0.692308      0.75      0.75
# activity                                          0.5       0.6     0.875
# name                                         0.818182       0.8       1.0
# person                                       0.555556  0.727273     0.875
# actor                                             0.6       0.7  0.666667
# ...                                               ...       ...       ...
# Wind motor                                   0.545455  0.692308  0.909091
# Windmill                                         0.75  0.833333       1.0
# wine                                         0.818182       0.8       1.0
# woman                                        0.833333  0.818182  0.857143
# zoo                                             0.875       1.0      0.75
#
#                  hen ostrich, Struthio camelus  ...  \
# company     0.888889                  0.764706  ...
# activity         1.0                       0.7  ...
# name             0.6                       0.8  ...
# person      0.714286                       0.7  ...
# actor            1.0                       0.5  ...
# ...              ...                       ...  ...
# Wind motor  0.909091                  0.647059  ...
# Windmill       0.875                  0.823529  ...
# wine             0.6                     0.875  ...
# woman       0.857143                    0.8125  ...
# zoo              1.0                     0.875  ...
#
#            buckeye, horse chestnut, conker coral fungus    agaric gyromitra  \
# company                           0.727273     0.714286       0.8  0.636364
# activity                               0.8     0.866667     0.625       0.6
# name                              0.777778     0.846154     0.875       0.8
# person                            0.545455     0.692308       0.9  0.833333
# actor                             0.636364     0.666667  0.571429  0.555556
# ...                                    ...          ...       ...       ...
# Wind motor                        0.642857         0.75  0.833333  0.583333
# Windmill                          0.916667     0.866667       0.9  0.833333
# wine                              0.777778     0.928571     0.875  0.909091
# woman                                  0.8     0.769231  0.888889       0.7
# zoo                                  0.875     0.916667       1.0  0.888889
#
#            stinkhorn, carrion fungus earthstar  \
# company                     0.714286  0.916667
# activity                    0.785714       0.8
# name                        0.846154      0.75
# person                           0.6  0.666667
# actor                       0.666667     0.625
# ...                              ...       ...
# Wind motor                  0.583333  0.846154
# Windmill                    0.833333       1.0
# wine                             0.8  0.888889
# woman                       0.769231       0.9
# zoo                         0.888889       1.0
#
#            hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa  \
# company                                              0.733333
# activity                                             0.866667
# name                                                 0.833333
# person                                               0.615385
# actor                                                0.769231
# ...                                                       ...
# Wind motor                                           0.571429
# Windmill                                             0.692308
# wine                                                 0.727273
# woman                                                    0.75
# zoo                                                  0.909091
#
#               bolete ear, spike, capitulum  \
# company     0.909091              0.666667
# activity         0.9              0.636364
# name           0.875                   0.6
# person      0.777778              0.666667
# actor           0.75              0.666667
# ...              ...                   ...
# Wind motor  0.833333              0.714286
# Windmill         0.9                  0.75
# wine           0.875                  0.75
# woman       0.888889              0.833333
# zoo         0.833333                   1.0
#
#            toilet tissue, toilet paper, bathroom tissue
# company                                        0.769231
# activity                                           0.75
# name                                           0.769231
# person                                         0.636364
# actor                                               0.6
# ...                                                 ...
# Wind motor                                          0.6
# Windmill                                       0.833333
# wine                                                0.8
# woman                                          0.785714
# zoo                                            0.888889
#
# [783 rows x 1000 columns]

# %%
nan = dataframe_jaccard.astype(float)
highest_values_nan_max = nan.apply(lambda s: s.abs().nsmallest(3).index.tolist(), axis=0)
highest_values_nan_max
# Out:
#   tench, Tinca tinca goldfish, Carassius auratus  \
# 0     train carriage                   guitarist
# 1             insect              musical artist
# 2          scientist      classical music artist
#
#   great white shark, white shark, man-eater, man-eating shark, Carcharodon caharias',  \
# 0                                 animanga character
# 1                                           ski area
# 2                                      figure skater
#
#   tiger shark, Galeocerdo cuvieri hammerhead, hammerhead shark  \
# 0                   figure skater                        drama
# 1                  clerical order                 speed skater
# 2           periodical literature                     ski area
#
#   electric ray, crampfish, numbfish, torpedo      stingray    cock     hen  \
# 0                             protected area  organisation    lock    gene
# 1                                time period     guitarist    book  shrine
# 2                                    article       gymnast  rocket    name
#
#   ostrich, Struthio camelus  ... buckeye, horse chestnut, conker  \
# 0      anatomical structure  ...               soccer tournoment
# 1          comics character  ...                naruto character
# 2   architectural structure  ...                  country estate
#
#            coral fungus    agaric      gyromitra stinkhorn, carrion fungus  \
# 0  soccer league season   glacier  agglomeration                 historian
# 1         soccer league     vicar          mayor        formula one racing
# 2           golf course  aircraft   organisation      soccer league season
#
#   earthstar  \
# 0   theatre
# 1    stream
# 2    skater
#
#   hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa  \
# 0                                      radio station
# 1                                   fashion designer
# 2              Controlled designation of origin wine
#
#        bolete        ear, spike, capitulum  \
# 0       hotel                         area
# 1       noble  classical music composition
# 2  automobile                         year
#
#   toilet tissue, toilet paper, bathroom tissue
# 0                            tennis tournament
# 1                             comics character
# 2                               historic place
#
# [3 rows x 1000 columns]

# %%
from pathlib import Path  

filepath = Path('../evaluation/files/jaccard_top3.csv')  

filepath.parent.mkdir(parents=True, exist_ok=True)  

highest_values_nan_max.to_csv(filepath, index=False)

# %% [markdown]
# Levenshtein

# %%
dataframe_lev = pd.DataFrame(index =db_list ,columns =img_net_list)

# %%
from nltk.metrics import edit_distance

# %%
for i in range(0,len(img_net_list)):
    for a in range(0,len(db_list)):
        if len(img_net_list[i].split(",")) > 1:
            max_val = 10000000.0
            for el in img_net_list[i].split(","):
                el_val = edit_distance(el, db_list[a], substitution_cost=1, transpositions=False)

                if el_val < max_val:
                    max_val = el_val
            dataframe_lev.iat[a,i] = max_val
        else:
            first = set(img_net_list[i])
            second = set(db_list[a])
            dataframe_lev.iat[a,i] = edit_distance(img_net_list[i], db_list[a], substitution_cost=1, transpositions=False)

# %%
dataframe_lev
# Out:
#            tench, Tinca tinca goldfish, Carassius auratus  \
# company                   1.0                         1.0
# activity                  1.0                         1.0
# name                      1.0                         1.0
# person                    1.0                         1.0
# actor                     1.0                         1.0
# ...                       ...                         ...
# Wind motor                1.0                         1.0
# Windmill                  1.0                         1.0
# wine                      1.0                         1.0
# woman                     1.0                         1.0
# zoo                       1.0                         1.0
#
#            great white shark, white shark, man-eater, man-eating shark, Carcharodon caharias',  \
# company                                                   1.0
# activity                                                  1.0
# name                                                      1.0
# person                                                    1.0
# actor                                                     1.0
# ...                                                       ...
# Wind motor                                                1.0
# Windmill                                                  1.0
# wine                                                      1.0
# woman                                                     1.0
# zoo                                                       1.0
#
#            tiger shark, Galeocerdo cuvieri hammerhead, hammerhead shark  \
# company                                1.0                          1.0
# activity                               1.0                          1.0
# name                                   1.0                          1.0
# person                                 1.0                          1.0
# actor                                  1.0                          1.0
# ...                                    ...                          ...
# Wind motor                             1.0                          1.0
# Windmill                               1.0                          1.0
# wine                                   1.0                          1.0
# woman                                  1.0                          1.0
# zoo                                    1.0                          1.0
#
#            electric ray, crampfish, numbfish, torpedo stingray cock hen  \
# company                                           1.0        7    5   6
# activity                                          1.0        6    7   8
# name                                              1.0        7    4   4
# person                                            1.0        8    6   4
# actor                                             1.0        7    4   5
# ...                                               ...      ...  ...  ..
# Wind motor                                        1.0        9    9   9
# Windmill                                          1.0        7    8   7
# wine                                              1.0        6    4   3
# woman                                             1.0        7    4   4
# zoo                                               1.0        8    3   3
#
#            ostrich, Struthio camelus  ... buckeye, horse chestnut, conker  \
# company                          1.0  ...                             1.0
# activity                         1.0  ...                             1.0
# name                             1.0  ...                             1.0
# person                           1.0  ...                             1.0
# actor                            1.0  ...                             1.0
# ...                              ...  ...                             ...
# Wind motor                       1.0  ...                             1.0
# Windmill                         1.0  ...                             1.0
# wine                             1.0  ...                             1.0
# woman                            1.0  ...                             1.0
# zoo                              1.0  ...                             1.0
#
#            coral fungus agaric gyromitra stinkhorn, carrion fungus earthstar  \
# company               9      7         7                       1.0         9
# activity             11      6         7                       1.0         7
# name                 11      5         8                       1.0         8
# person               10      6         8                       1.0         7
# actor                11      5         7                       1.0         6
# ...                 ...    ...       ...                       ...       ...
# Wind motor           11     10         8                       1.0         8
# Windmill             12      7         7                       1.0         9
# wine                 11      6         8                       1.0         9
# woman                 9      6         7                       1.0         8
# zoo                  11      6         8                       1.0         9
#
#            hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa  \
# company                                                   1.0
# activity                                                  1.0
# name                                                      1.0
# person                                                    1.0
# actor                                                     1.0
# ...                                                       ...
# Wind motor                                                1.0
# Windmill                                                  1.0
# wine                                                      1.0
# woman                                                     1.0
# zoo                                                       1.0
#
#            bolete ear, spike, capitulum  \
# company         6                   1.0
# activity        7                   1.0
# name            5                   1.0
# person          6                   1.0
# actor           6                   1.0
# ...           ...                   ...
# Wind motor      9                   1.0
# Windmill        8                   1.0
# wine            5                   1.0
# woman           5                   1.0
# zoo             5                   1.0
#
#            toilet tissue, toilet paper, bathroom tissue
# company                                             1.0
# activity                                            1.0
# name                                                1.0
# person                                              1.0
# actor                                               1.0
# ...                                                 ...
# Wind motor                                          1.0
# Windmill                                            1.0
# wine                                                1.0
# woman                                               1.0
# zoo                                                 1.0
#
# [783 rows x 1000 columns]

# %%
nan = dataframe_lev.astype(float)
highest_values_nan_max = nan.apply(lambda s: s.abs().nsmallest(3).index.tolist(), axis=0)
highest_values_nan_max
# Out:
#   tench, Tinca tinca goldfish, Carassius auratus  \
# 0            company                     company
# 1           activity                    activity
# 2               name                        name
#
#   great white shark, white shark, man-eater, man-eating shark, Carcharodon caharias',  \
# 0                                            company
# 1                                           activity
# 2                                               name
#
#   tiger shark, Galeocerdo cuvieri hammerhead, hammerhead shark  \
# 0                         company                      company
# 1                        activity                     activity
# 2                            name                         name
#
#   electric ray, crampfish, numbfish, torpedo stingray   cock   hen  \
# 0                                    company  mineral   lock  chef
# 1                                   activity   winery   book   sea
# 2                                       name   single  coach  vein
#
#   ostrich, Struthio camelus  ... buckeye, horse chestnut, conker coral fungus  \
# 0                   company  ...                         company       fungus
# 1                  activity  ...                        activity  road tunnel
# 2                      name  ...                            name     coal pit
#
#    agaric gyromitra stinkhorn, carrion fungus   earthstar  \
# 0   award   Pyramid                   company      artist
# 1  cleric     comic                  activity  earthquake
# 2   comic  criminal                      name        star
#
#   hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa  \
# 0                                            company
# 1                                           activity
# 2                                               name
#
#     bolete ear, spike, capitulum toilet tissue, toilet paper, bathroom tissue
# 0     bone               company                                      company
# 1  college              activity                                     activity
# 2     poet                  name                                         name
#
# [3 rows x 1000 columns]
