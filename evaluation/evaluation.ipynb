# %%
import pandas as pd

test = pd.read_csv("./files/wiki_2_vec_top3_max.csv")

# %%
pd.set_option('display.max_columns', 100)
test.head(50)
# Out:
#   tench, Tinca tinca goldfish, Carassius auratus  \
# 0               fish                        fish
# 1         crustacean                     species
# 2             guitar                         cat
#
#   great white shark, white shark, man-eater, man-eating shark, Carcharodon caharias',  \
# 0                                               fish
# 1                                        brown dwarf
# 2                    Member of a Resistance Movement
#
#   tiger shark, Galeocerdo cuvieri hammerhead, hammerhead shark  \
# 0                         species                         fish
# 1                            fish                   crustacean
# 2                             cat                      reptile
#
#   electric ray, crampfish, numbfish, torpedo    stingray   cock  \
# 0                                    species        fish    dog
# 1                                       fish  crustacean   bird
# 2                                       ship      surfer  horse
# ...

# %%
mean = pd.read_csv("./files/wiki_2_vec_top3_mean.csv")
pd.set_option('display.max_columns', 100)
mean.head(50)
# Out:
#   tench, Tinca tinca goldfish, Carassius auratus  \
# 0               fish                        fish
# 1         crustacean                         cat
# 2             guitar                  crustacean
#
#   great white shark, white shark, man-eater, man-eating shark, Carcharodon caharias',  \
# 0                                               fish
# 1                                        brown dwarf
# 2                                                dog
#
#   tiger shark, Galeocerdo cuvieri hammerhead, hammerhead shark  \
# 0                            fish                         fish
# 1                         reptile                     arachnid
# 2                         species                   crustacean
#
#   electric ray, crampfish, numbfish, torpedo    stingray   cock  \
# 0                                       fish        fish    dog
# 1                                    species  crustacean   bird
# 2                                brown dwarf      surfer  horse
# ...

# %%
mean = pd.read_csv("./files/levenshtein_top3.csv")
mean
# Out:
#   tench, Tinca tinca goldfish, Carassius auratus  \
# 0              beach                        fish
# 1              genre                     glacier
# 2             tenure                   biologist
#
#   great white shark, white shark, man-eater, man-eating shark, Carcharodon caharias',  \
# 0                                                Spy
# 1                                                sea
# 2                                                dam
#
#   tiger shark, Galeocerdo cuvieri hammerhead, hammerhead shark  \
# 0                         library                       camera
# 1                      video game                     asteroid
# 2                         mineral                     bacteria
#
#   electric ray, crampfish, numbfish, torpedo stingray   cock   hen  \
# 0                                       type  mineral   lock  chef
# 1                                     stream   winery   book   sea
# ...

# %%
mean = pd.read_csv("./files/wiki_2_vec_top3_mean.csv")
pd.set_option('display.max_columns', 100)
mean.head(50)
# Out:
#   tench, Tinca tinca goldfish, Carassius auratus  \
# 0               fish                        fish
# 1         crustacean                         cat
# 2             guitar                  crustacean
#
#   great white shark, white shark, man-eater, man-eating shark, Carcharodon caharias',  \
# 0                                               fish
# 1                                        brown dwarf
# 2                                                dog
#
#   tiger shark, Galeocerdo cuvieri hammerhead, hammerhead shark  \
# 0                            fish                         fish
# 1                         reptile                     arachnid
# 2                         species                   crustacean
#
#   electric ray, crampfish, numbfish, torpedo    stingray   cock  \
# 0                                       fish        fish    dog
# 1                                    species  crustacean   bird
# 2                                brown dwarf      surfer  horse
# ...

# %%
import numpy as np
img_net = pd.read_csv("../notebooks/files/ImageNet.csv")
img_net_list = img_net["Class Name"].tolist()

# %%
wiki_mean = pd.read_csv("./files/wiki_2_vec_top3_mean.csv")
wiki_max = pd.read_csv("./files/wiki_2_vec_top3_max.csv")
word_mean = pd.read_csv("./files/word_2_vec_top3_mean.csv")
word_max = pd.read_csv("./files/word_2_vec_top3_max.csv")

# %%
d = pd.DataFrame("", index=np.arange(3), columns=img_net_list)

# %% [markdown]
# we do a left join so we have 1000 columns, and every column that doesnt exist has emtpy values

# %%
d.update(wiki_mean, join='left', overwrite=True)

# %%
d
# Out:
#   tench, Tinca tinca goldfish, Carassius auratus  \
# 0               fish                        fish
# 1         crustacean                         cat
# 2             guitar                  crustacean
#
#   great white shark, white shark, man-eater, man-eating shark, Carcharodon caharias',  \
# 0                                               fish
# 1                                        brown dwarf
# 2                                                dog
#
#   tiger shark, Galeocerdo cuvieri hammerhead, hammerhead shark  \
# 0                            fish                         fish
# 1                         reptile                     arachnid
# 2                         species                   crustacean
#
#   electric ray, crampfish, numbfish, torpedo    stingray   cock  \
# 0                                       fish        fish    dog
# 1                                    species  crustacean   bird
# 2                                brown dwarf      surfer  horse
# ...

# %%
from pathlib import Path  

filepath = Path('./processed_files/word_2_vec_top3_max.csv')  

filepath.parent.mkdir(parents=True, exist_ok=True)  

d.to_csv(filepath, index=False)

# %%
for column in mean:
    print(column)
# Out:
# tench, Tinca tinca
# goldfish, Carassius auratus
# great white shark, white shark, man-eater, man-eating shark, Carcharodon caharias',
# tiger shark, Galeocerdo cuvieri
# hammerhead, hammerhead shark
# electric ray, crampfish, numbfish, torpedo
# stingray
# cock
# hen
# ostrich, Struthio camelus
# brambling, Fringilla montifringilla
# goldfinch, Carduelis carduelis
# house finch, linnet, Carpodacus mexicanus
# junco, snowbird
# indigo bunting, indigo finch, indigo bird, Passerina cyanea
# robin, American robin, Turdus migratorius
# bulbul
# jay
# magpie
# chickadee
# water ouzel, dipper
# kite
# bald eagle, American eagle, Haliaeetus leucocephalus
# vulture
# great grey owl, great gray owl, Strix nebulosa
# European fire salamander, Salamandra salamandra
# common newt, Triturus vulgaris
# eft
# spotted salamander, Ambystoma maculatum
# axolotl, mud puppy, Ambystoma mexicanum
# bullfrog, Rana catesbeiana
# tree frog, tree-frog
# ...
