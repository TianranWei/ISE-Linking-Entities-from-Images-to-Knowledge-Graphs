# %%
import pandas as pd

test = pd.read_csv("./files/wiki_2_vec_top3_max.csv")

# %%
pd.set_option('display.max_columns', 100)
test.head(50)
# Out:
#   tench, Tinca tinca goldfish, Carassius auratus  \
# 0   volleyball coach                 brown dwarf
# 1  water polo Player               body of water
# 2         rugby club          animanga character
#
#   great white shark, white shark, man-eater, man-eating shark, Carcharodon caharias',  \
# 0                                        brown dwarf
# 1                    Member of a Resistance Movement
# 2  ancient area of jurisdiction of a person (feud...
#
#   tiger shark, Galeocerdo cuvieri hammerhead, hammerhead shark  \
# 0                   serial killer                serial killer
# 1                 taxonomic group                  storm surge
# 2                     brown dwarf                   water ride
#
#           electric ray, crampfish, numbfish, torpedo            stingray  \
# 0                              electrical substation  television episode
# 1                                        brown dwarf       rocket engine
# ...

# %%
mean = pd.read_csv("./files/wiki_2_vec_top3_mean.csv")
pd.set_option('display.max_columns', 100)
mean.head(50)
# Out:
#   tench, Tinca tinca goldfish, Carassius auratus  \
# 0         green alga                 brown dwarf
# 1        brown dwarf                  green alga
# 2    taxonomic group               body of water
#
#   great white shark, white shark, man-eater, man-eating shark, Carcharodon caharias',  \
# 0                                        brown dwarf
# 1                                      body of water
# 2                                      serial killer
#
#   tiger shark, Galeocerdo cuvieri hammerhead, hammerhead shark  \
# 0                     brown dwarf                serial killer
# 1                 taxonomic group                  storm surge
# 2                   serial killer             naruto character
#
#           electric ray, crampfish, numbfish, torpedo            stingray  \
# 0                                        brown dwarf  television episode
# 1                                      rocket engine       rocket engine
# ...
